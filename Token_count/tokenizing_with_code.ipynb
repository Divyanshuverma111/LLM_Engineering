# %%
# Tokenizing with code
import tiktoken
encoding = tiktoken.get_encoding("cl100k_base")
text = "Hello, how are you doing today?"
tokens = encoding.encode(text)

# %%
tokens
# Out:
# [9906, 11, 1268, 527, 499, 3815, 3432, 30]

# %%
for token_id in tokens:
    print(f"Token ID: {token_id}, Token: {encoding.decode([token_id])}")
# Out:
# Token ID: 9906, Token: Hello
# Token ID: 11, Token: ,
# Token ID: 1268, Token:  how
# Token ID: 527, Token:  are
# Token ID: 499, Token:  you
# Token ID: 3815, Token:  doing
# Token ID: 3432, Token:  today
# Token ID: 30, Token: ?
